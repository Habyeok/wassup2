# %% [markdown]
# # 클래스

# %%
# 계산기 프로그램 함수로 만들기

result = 0

def add(num):
    global result
    result += num  # 결괏값(result)에 입력값(num) 더하기
    return result  # 결괏값 리턴

print(add(3))
print(add(4))
# Out:
# 3
# 7

# %%
def add(num):
    result = 0 # 새롭게 값을 입력할 때마다 리셋된다. 누적이 안 된다.
    result += num  # 결괏값(result)에 입력값(num) 더하기
    return result  # 결괏값 리턴

print(add(3))
print(add(4)) # 새로운 입력값에 대한 계산만 이루어진다.
# Out:
# 3
# 4

# %%
# 한 프로그램에 두 개의 계산기

result1 = 0
result2 = 0

def add1(num):  # 계산기1
    global result1
    result1 += num
    return result1

def add2(num):  # 계산기2
    global result2
    result2 += num
    return result2

print(add1(3))
print(add1(4))
print(add2(3))
print(add2(7))
# Out:
# 3
# 7
# 3
# 10

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result

cal1 = Calculator() # 인스턴스
cal2 = Calculator()

print(cal1.add(3))
print(cal1.add(4))
print(cal2.add(3))
print(cal2.add(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# Calculator 클래스로 만든 별개의 계산기 cal1, cal2(파이썬에서는 이것을 ‘객체’라고 부른다)가 각각의 역할을 수행한다.
# 그리고 계산기의 결괏값 역시 다른 계산기의 결괏값과 상관없이 독립적인 값을 유지한다.
# 이렇게 클래스를 사용하면 계산기 대수가 늘어나도 객체를 생성하면 되므로 함수만 사용할 때보다 간단하게 프로그램을 작성할 수 있다.

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result

    def sub(self, num):
        self.result -= num
        return self.result

# %% [markdown]
# ## 클래스와 객체

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Cookie:
    pass

# %%
a = Cookie()
b = Cookie()

# %%
a, b
# Out:
# (<__main__.Cookie at 0x1ed6ab3de90>, <__main__.Cookie at 0x1ed6ab3b450>)

# %% [markdown]
# ## 사칙 연산 클래스 만들기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 인풋/아웃풋 정의

# %%
# 클래스 구조 만들기

class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

# %%
a = FourCal()

# %%
a, type(a)
# Out:
# (<__main__.FourCal at 0x1ed6ab3b7d0>, __main__.FourCal)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = FourCal()
FourCal.setdata(a, 4, 2)
a.setdata(4, 2)

# %%
a.first
# Out:
# 4

# %%
a.second
# Out:
# 2

# %%
a = FourCal() # 빵틀로 빵 만들기
b = FourCal()

# %%
a.setdata(4, 2)
a.first
# Out:
# 4

# %%
b.setdata(3, 7)
b.first
# Out:
# 3

# %% [markdown]
# ### 더하기 기능 만들기

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second
    def add(self):
        result = self.first + self.second
        return result

# %%
a = FourCal()
a.setdata(4, 2)

# %%
c = a.add()
c
# Out:
# 6

# %% [markdown]
# ### 곱하기, 빼기, 나누기 기능 만들기

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second
    def add(self):
        result = self.first + self.second
        return result
    def sub(self):
        result = self.first - self.second
        return result
    def mul(self):
        result = self.first * self.second
        return result
    def div(self):
        result = self.first / self.second
        return result

# %%
a = FourCal(4, 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 a = FourCal(4, 2)
#
# TypeError: FourCal() takes no arguments

# %%
a = FourCal()
b = FourCal()

a.setdata(4, 2)
b.setdata(3, 8)

# %%
a.add()
# Out:
# 6

# %%
a.mul()
# Out:
# 8

# %%
a.sub()
# Out:
# 2

# %%
a.div()
# Out:
# 2.0

# %%
b.add()
# Out:
# 11

# %%
b.mul()
# Out:
# 24

# %%
b.sub()
# Out:
# -5

# %%
b.div()
# Out:
# 0.375

# %% [markdown]
# ## 생성자

# %%
class FourCal:
    def __init__(self, first, second):
         self.first = first
         self.second = second
    def setdata(self, first, second): # setdata 할 필요 없이 __init__ 사용
        self.first = first
        self.second = second
    def add(self):
        result = self.first + self.second
        return result
    def sub(self):
        result = self.first - self.second
        return result
    def mul(self):
        result = self.first * self.second
        return result
    def div(self):
        result = self.first / self.second
        return result

# %%
a = FourCal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 a = FourCal()
#
# TypeError: FourCal.__init__() missing 2 required positional arguments: 'first' and 'second'

# %%
a = FourCal(4, 2)
# a.setdata(4, 2) 안 해도 됨

# %%
a.first
# Out:
# 4

# %%
a.second
# Out:
# 2

# %%
a.add()
# Out:
# 6

# %%
a.div()
# Out:
# 2.0

# %% [markdown]
# ## 클래스의 상속

# %%
class MoreFourCal(FourCal):
    pass

# %%
a = MoreFourCal(4, 2)

# %%
a.add()
# Out:
# 6

# %%
a.mul()
# Out:
# 8

# %%
a.sub()
# Out:
# 2

# %%
a.div()
# Out:
# 2.0

# %%
class MoreFourCal(FourCal):
    def pow(self):
        result = self.first ** self.second
        return result

# %%
a = MoreFourCal(4, 2)
a.pow()
# Out:
# 16

# %%
a.add()
# Out:
# 6

# %% [markdown]
# ## 메서드 오버라이딩

# %%
a = FourCal(4, 0)

# %%
a.div()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 a.div()
#
# Cell In[50], line 18, in FourCal.div(self)
#      17 def div(self):
# ---> 18     result = self.first / self.second
#      19     return result
#
# ZeroDivisionError: division by zero

# %%
class SafeFourCal(FourCal):
    def div(self):
        if self.second == 0:
            return 0
        else:
            return self.first / self.second

# %%
a = SafeFourCal(4, 0)

# %%
a.div()
# Out:
# 0

# %% [markdown]
# ## 클래스변수

# %%
class Family:
    lastname = '김'

# %%
Family.lastname
# Out:
# '김'

# %%
a = Family()
b = Family()

# %%
a.lastname, b.lastname
# Out:
# ('김', '김')

# %%
Family.lastname = "박"

# %%
a.lastname
# Out:
# '박'

# %%
b.lastname
# Out:
# '박'

# %%
a.lastname = '최'

# %%
a.lastname
# Out:
# '최'

# %%
b.lastname
# Out:
# '박'

# %%
Family.lastname
# Out:
# '박'

# %% [markdown]
# # 예외처리

# %% [markdown]
# ## 오류는 언제 발생하는가?

# %%
# 존재하지 않는 파일을 사용하려고 시도했을 때
f = open("나없는파일", 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f = open("나없는파일", 'r')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '나없는파일'

# %%
# 0으로 다른 숫자를 나누는 경우
4 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 4 / 0
#
# ZeroDivisionError: division by zero

# %%
a = [1, 2, 3]
a[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 a = [1, 2, 3]
# ----> 2 a[3]
#
# IndexError: list index out of range

# %% [markdown]
# ## 오류 예외 처리 기법

# %% [markdown]
# ### try-except 문

# %%
# try-except만 쓰는 방법
try:
    ...
except:
    ...

# %%
# 발생 오류만 포함한 except 문
try:
    ...
except 발생오류:
    ...

# %%
# 발생 오류와 오류 변수까지 포함한 except 문
try:
    ...
except 발생오류 as 오류변수:
    ...

# %%
try:
    4/0
except:
    print('error') # 실제 에러가 난 게 아니라 정상 동작한 것
# Out:
# error

# %%
try:
    4 / 0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# ### 여러 개의 오류 처리하기

# %%
try:
    a = [1,2]
    print(a[3])
    4/0
except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")
except IndexError:
    print("인덱싱 할 수 없습니다.")
# Out:
# 인덱싱 할 수 없습니다.

# %%
try:
    a = [1,2]
    print(a[3])
    4/0
except ZeroDivisionError as e:
    print(e)
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    a = [1,2]
    print(a[3])
    4/0
except (ZeroDivisionError, IndexError) as e:
    print(e)
# Out:
# list index out of range

# %% [markdown]
# ### try-else 문

# %%
try:
    age=int(input('나이를 입력하세요: '))
except:
    print('입력이 정확하지 않습니다.')
else:
    if age <= 18:
        print('미성년자는 출입금지입니다.')
    else:
        print('환영합니다.')
# Out:
# 나이를 입력하세요: 25
# 환영합니다.

# %% [markdown]
# ## 오류 회피하기

# %%
try:
    f = open("나없는파일", 'r')
except FileNotFoundError:
    pass
